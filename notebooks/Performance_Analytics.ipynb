# %% [markdown]
# # Performance Analytics\n\nDay 4 fund performance analytics.\n

# %%
# %run ../scripts/performance_analytics.py\n

# %% [markdown]
# Outputs: `fund_scorecard.csv`, `alpha_beta.csv`, and benchmark comparison chart.\n
