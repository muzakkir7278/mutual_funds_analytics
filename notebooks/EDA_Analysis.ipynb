# %% [markdown]
# # EDA Analysis
#
# Day 3 exploratory data analysis for Mutual Fund Analytics.

# %% [markdown]
# ## Run the EDA script
# This notebook calls the Python script that generates the PNG charts and findings.

# %%
# %run ../scripts/eda_analysis.py

# %% [markdown]
# ## Outputs
# - PNG charts are exported to `reports/charts/`
# - EDA findings are saved to `reports/eda_findings.md`
